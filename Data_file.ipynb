# %%
import pandas as pd
import numpy as np
df = pd.read_csv('C:\\Users\\fresh\\Desktop\\MY_COURSES\\3_TRESTLE_ACADEMY\\Data_Engineering_Track\\trestle_academy_dataset.csv')
df
# Out:
#     student_id          name  age  gender            course enrollment_date  \
# 0        S0001     Student_1   30  Female      Data Science      2023-03-22
# 1        S0002     Student_2   33  Female      Data Science      2023-01-29
# 2        S0003     Student_3   39  Female  Data Engineering      2023-12-24
# 3        S0004     Student_4   18    Male  Data Engineering      2023-01-09
# 4        S0005     Student_5   21  Female   Cloud Computing      2023-05-26
# ..         ...           ...  ...     ...               ...             ...
# 995      S0996   Student_996   25  Female  Data Engineering      2023-05-25
# 996      S0997   Student_997   40    Male   AI Fundamentals      2023-08-15
# 997      S0998   Student_998   20  Female   Cloud Computing      2023-04-22
# 998      S0999   Student_999   40  Female   Cloud Computing      2023-07-04
# 999      S1000  Student_1000   34    Male   AI Fundamentals      2023-09-09
#
#      final_grade is_intern
# 0             97        No
# 1             64        No
# 2             97        No
# 3             89       Yes
# 4             65        No
# ..           ...       ...
# 995           52       Yes
# 996           90        No
# 997          100        No
# 998           67        No
# 999           90       Yes
#
# [1000 rows x 8 columns]

# %%
#importing library
from ydata_profiling import ProfileReport
#defining the library
profile = ProfileReport(df)
# exporting your report as a html file
profile.to_file(output_file='report.html')
# Out:
# 2024-11-22 09:50:48,754 - INFO     - Pandas backend loaded 2.2.2
# 2024-11-22 09:50:48,791 - INFO     - Numpy backend loaded 1.26.4
# 2024-11-22 09:50:48,848 - INFO     - Pyspark backend NOT loaded
# 2024-11-22 09:50:48,848 - INFO     - Python backend loaded
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import dtale 

import dtale.app as dtale_app
dtale_app.USE_Firefox = True
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://0.0.0.0:40000/dtale/iframe/5"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# 2024-11-22 10:34:51,796 - INFO     - Executing shutdown due to inactivity...
# 2024-11-22 10:53:02,996 - INFO     - Executing shutdown due to inactivity...
# 2024-11-22 10:54:29,989 - INFO     - Executing shutdown due to inactivity...
# 2024-11-22 10:54:45,701 - INFO     - Executing shutdown due to inactivity...
# 2024-11-22 10:56:40,817 - INFO     - Executing shutdown due to inactivity...

# %%
pip install autoviz
# Out:
# Collecting autoviz
#   Downloading autoviz-0.1.905-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: xlrd in c:\users\fresh\anaconda3\lib\site-packages (from autoviz) (2.0.1)
# Requirement already satisfied: wordcloud in c:\users\fresh\anaconda3\lib\site-packages (from autoviz) (1.9.4)
# Collecting emoji (from autoviz)
#   Downloading emoji-2.14.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting pyamg (from autoviz)
#   Downloading pyamg-5.2.1-cp312-cp312-win_amd64.whl.metadata (8.3 kB)
# Requirement already satisfied: scikit-learn in c:\users\fresh\anaconda3\lib\site-packages (from autoviz) (1.5.1)
# Requirement already satisfied: statsmodels in c:\users\fresh\anaconda3\lib\site-packages (from autoviz) (0.14.2)
# Requirement already satisfied: nltk in c:\users\fresh\anaconda3\lib\site-packages (from autoviz) (3.9.1)
# Collecting textblob (from autoviz)
#   Downloading textblob-0.18.0.post0-py3-none-any.whl.metadata (4.5 kB)
# Collecting xgboost<1.7,>=0.82 (from autoviz)
#   Downloading xgboost-1.6.2-py3-none-win_amd64.whl.metadata (1.8 kB)
# Requirement already satisfied: fsspec>=0.8.3 in c:\users\fresh\anaconda3\lib\site-packages (from autoviz) (2024.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\fresh\anaconda3\lib\site-packages (from autoviz) (4.11.0)
# Collecting pandas-dq>=1.29 (from autoviz)
#   Downloading pandas_dq-1.29-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.24.0 in c:\users\fresh\anaconda3\lib\site-packages (from autoviz) (1.26.4)
# Requirement already satisfied: hvplot>=0.9.2 in c:\users\fresh\anaconda3\lib\site-packages (from autoviz) (0.11.0)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\fresh\anaconda3\lib\site-packages (from autoviz) (1.19.1)
# Requirement already satisfied: panel>=1.4.0 in c:\users\fresh\anaconda3\lib\site-packages (from autoviz) (1.5.2)
# Requirement already satisfied: pandas>=2.0 in c:\users\fresh\anaconda3\lib\site-packages (from autoviz) (2.2.2)
# Requirement already satisfied: matplotlib>3.7.4 in c:\users\fresh\anaconda3\lib\site-packages (from autoviz) (3.9.2)
# Requirement already satisfied: seaborn>0.12.2 in c:\users\fresh\anaconda3\lib\site-packages (from autoviz) (0.13.2)
# Requirement already satisfied: bokeh>=3.1 in c:\users\fresh\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.6.0)
# Requirement already satisfied: colorcet in c:\users\fresh\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.1.0)
# Requirement already satisfied: packaging in c:\users\fresh\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (24.1)
# Requirement already satisfied: param<3.0,>=2.0 in c:\users\fresh\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (2.1.1)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\fresh\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\fresh\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\fresh\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fresh\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\fresh\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\fresh\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\fresh\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\fresh\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\fresh\anaconda3\lib\site-packages (from pandas>=2.0->autoviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\fresh\anaconda3\lib\site-packages (from pandas>=2.0->autoviz) (2023.3)
# Requirement already satisfied: bleach in c:\users\fresh\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (4.1.0)
# Requirement already satisfied: linkify-it-py in c:\users\fresh\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (2.0.0)
# Requirement already satisfied: markdown in c:\users\fresh\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\fresh\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\fresh\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (0.3.0)
# Requirement already satisfied: requests in c:\users\fresh\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\fresh\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (4.66.5)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\fresh\anaconda3\lib\site-packages (from scikit-learn->autoviz) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\fresh\anaconda3\lib\site-packages (from scikit-learn->autoviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\fresh\anaconda3\lib\site-packages (from scikit-learn->autoviz) (3.5.0)
# Requirement already satisfied: click in c:\users\fresh\anaconda3\lib\site-packages (from nltk->autoviz) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\fresh\anaconda3\lib\site-packages (from nltk->autoviz) (2024.9.11)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\fresh\anaconda3\lib\site-packages (from statsmodels->autoviz) (0.5.6)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\fresh\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.1.4)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\fresh\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\fresh\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\fresh\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (2022.9.0)
# Requirement already satisfied: six in c:\users\fresh\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels->autoviz) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\fresh\anaconda3\lib\site-packages (from bleach->panel>=1.4.0->autoviz) (0.5.1)
# Requirement already satisfied: colorama in c:\users\fresh\anaconda3\lib\site-packages (from click->nltk->autoviz) (0.4.6)
# Requirement already satisfied: uc-micro-py in c:\users\fresh\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.4.0->autoviz) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users
5 MB/s eta 0:00:07
#    ----------------------------- ---------- 91.2/125.4 MB 5.5 MB/s eta 0:00:07
#    ----------------------------- ---------- 92.5/125.4 MB 5.6 MB/s eta 0:00:06
#    ------------------------------ --------- 94.1/125.4 MB 5.6 MB/s eta 0:00:06
#    ------------------------------ --------- 95.4/125.4 MB 5.6 MB/s eta 0:00:06
#    ------------------------------ --------- 97.0/125.4 MB 5.6 MB/s eta 0:00:06
#    ------------------------------- -------- 98.6/125.4 MB 5.6 MB/s eta 0:00:05
#    ------------------------------- -------- 100.1/125.4 MB 5.6 MB/s eta 0:00:05
#    -------------------------------- ------- 101.7/125.4 MB 5.7 MB/s eta 0:00:05
#    -------------------------------- ------- 103.0/125.4 MB 5.7 MB/s eta 0:00:04
#    --------------------------------- ------ 104.6/125.4 MB 5.7 MB/s eta 0:00:04
#    --------------------------------- ------ 105.9/125.4 MB 5.7 MB/s eta 0:00:04
#    ---------------------------------- ----- 107.2/125.4 MB 5.7 MB/s eta 0:00:04
#    ---------------------------------- ----- 108.3/125.4 MB 5.7 MB/s eta 0:00:04
#    ---------------------------------- ----- 109.6/125.4 MB 5.7 MB/s eta 0:00:03
#    ----------------------------------- ---- 111.1/125.4 MB 5.7 MB/s eta 0:00:03
#    ----------------------------------- ---- 112.5/125.4 MB 5.7 MB/s eta 0:00:03
#    ------------------------------------ --- 113.8/125.4 MB 5.7 MB/s eta 0:00:03
#    ------------------------------------ --- 115.3/125.4 MB 5.7 MB/s eta 0:00:02
#    ------------------------------------- -- 116.4/125.4 MB 5.7 MB/s eta 0:00:02
#    ------------------------------------- -- 118.5/125.4 MB 5.8 MB/s eta 0:00:02
#    -------------------------------------- - 119.5/125.4 MB 5.8 MB/s eta 0:00:02
#    -------------------------------------- - 120.6/125.4 MB 5.8 MB/s eta 0:00:01
#    -------------------------------------- - 121.9/125.4 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  123.5/125.4 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  125.0/125.4 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  125.3/125.4 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  125.3/125.4 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 125.4/125.4 MB 5.7 MB/s eta 0:00:00
# Downloading emoji-2.14.0-py3-none-any.whl (586 kB)
#    ---------------------------------------- 0.0/586.9 kB ? eta -:--:--
#    ---------------------------------------- 586.9/586.9 kB 5.2 MB/s eta 0:00:00
# Downloading pyamg-5.2.1-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------------- ------------- 1.0/1.6 MB 5.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.6 MB 5.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.6 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 1.8 MB/s eta 0:00:00
# Downloading textblob-0.18.0.post0-py3-none-any.whl (626 kB)
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 626.3/626.3 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: emoji, xgboost, pyamg, textblob, pandas-dq, autoviz
# Successfully installed autoviz-0.1.905 emoji-2.14.0 pandas-dq-1.29 pyamg-5.2.1 textblob-0.18.0.post0 xgboost-1.6.2
# Note: you may need to restart the kernel to use updated packages.

# %%
df
# Out:
#     student_id      name      age  gender       course      enrollment_date  \
# 0      S0001       Student_1  30   Female      Data Science    2023-03-22
# 1      S0002       Student_2  33   Female      Data Science    2023-01-29
# 2      S0003       Student_3  39   Female  Data Engineering    2023-12-24
# 3      S0004       Student_4  18     Male  Data Engineering    2023-01-09
# 4      S0005       Student_5  21   Female   Cloud Computing    2023-05-26
# ..         ...           ...  ...     ...               ...             ...
# 995    S0996     Student_996  25   Female  Data Engineering    2023-05-25
# 996    S0997     Student_997  40     Male   AI Fundamentals    2023-08-15
# 997    S0998     Student_998  20   Female   Cloud Computing    2023-04-22
# 998    S0999     Student_999  40   Female   Cloud Computing    2023-07-04
# 999    S1000    Student_1000  34     Male   AI Fundamentals    2023-09-09
#
#      final_grade is_intern
# 0         97          No
# 1         64          No
# 2         97          No
# 3         89         Yes
# 4         65          No
# ..           ...       ...
# 995       52         Yes
# 996       90          No
# 997      100          No
# 998       67          No
# 999       90         Yes
#
# [1000 rows x 8 columns]

# %%
df=pd.read_csv('C:\\Users\\fresh\\Desktop\\MY_COURSES\\3_TRESTLE_ACADEMY\\Data_Engineering_Track\\trestle_academy_dataset.csv')

# %%
df
# Out:
#     student_id      name      age  gender       course      enrollment_date  \
# 0      S0001       Student_1  30   Female      Data Science    2023-03-22
# 1      S0002       Student_2  33   Female      Data Science    2023-01-29
# 2      S0003       Student_3  39   Female  Data Engineering    2023-12-24
# 3      S0004       Student_4  18     Male  Data Engineering    2023-01-09
# 4      S0005       Student_5  21   Female   Cloud Computing    2023-05-26
# ..         ...           ...  ...     ...               ...             ...
# 995    S0996     Student_996  25   Female  Data Engineering    2023-05-25
# 996    S0997     Student_997  40     Male   AI Fundamentals    2023-08-15
# 997    S0998     Student_998  20   Female   Cloud Computing    2023-04-22
# 998    S0999     Student_999  40   Female   Cloud Computing    2023-07-04
# 999    S1000    Student_1000  34     Male   AI Fundamentals    2023-09-09
#
#      final_grade is_intern
# 0         97          No
# 1         64          No
# 2         97          No
# 3         89         Yes
# 4         65          No
# ..           ...       ...
# 995       52         Yes
# 996       90          No
# 997      100          No
# 998       67          No
# 999       90         Yes
#
# [1000 rows x 8 columns]

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()

# %%
#you have to specify the target variable
dft = AV.AutoViz('train (3).csv', depVar = 'Survived')

# %%
dft = AV.AutoViz('C:\\Users\\fresh\\Desktop\\MY_COURSES\\3_TRESTLE_ACADEMY\\Data_Engineering_Track\\trestle_academy_dataset.csv', depVar = 'Survived')
# Out:
# Shape of your Data Set loaded: (1000, 8)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  0
#     Number of Integer-Categorical Columns =  2
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  2
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  1
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  2
#     Number of Columns to Delete =  0
#     8 Predictors classified...
#         2 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['student_id', 'name']
# Could not find given target var in data set. Please check input
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 dft = AV.AutoViz('C:\\Users\\fresh\\Desktop\\MY_COURSES\\3_TRESTLE_ACADEMY\\Data_Engineering_Track\\trestle_academy_dataset.csv', depVar = 'Survived')
#
# File c:\Users\fresh\anaconda3\Lib\site-packages\autoviz\AutoViz_Class.py:239, in AutoViz_Class.AutoViz(self, filename, sep, depVar, dfte, header, verbose, lowess, chart_format, max_rows_analyzed, max_cols_analyzed, save_plot_dir)
#     235     dft = AutoViz_Holo(filename, sep, dep_var, header, verbose,
#     236                        lowess, chart_format, max_rows_analyzed,
#     237                        max_cols_analyzed, save_plot_dir)
#     238 else:
# --> 239     dft = self.AutoViz_Main(filename, sep, dep_var, header, verbose,
#     240                             lowess, chart_format, max_rows_analyzed,
#     241                             max_cols_analyzed, save_plot_dir)
#     242 return dft
#
# File c:\Users\fresh\anaconda3\Lib\site-packages\autoviz\AutoViz_Class.py:274, in AutoViz_Class.AutoViz_Main(self, filename, sep, dep_var, header, verbose, lowess, chart_format, max_rows_analyzed, max_cols_analyzed, save_plot_dir)
#     271 ############   Start the clock here and classify variables in data set first ########
#     272 start_time = time.time()
# --> 274 (dft, dep_var, id_cols, bool_vars, cats, continuous_vars, discrete_string_vars, date_vars, classes,
#     275  problem_type, selected_cols) = classify_print_vars(filename, sep, max_rows_analyzed, max_cols_analyzed,
#     276                                                     dep_var, header, verbose)
#     278 ###########  This is where perform data quality checks on data ################
#     279 if verbose >= 1:
#
# ValueError: not enough values to unpack (expected 11, got 8)
