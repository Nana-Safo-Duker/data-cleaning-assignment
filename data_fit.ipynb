# %%
import pandas as pd
import datasist as ds  #import datasist library
import numpy as np

# %%
df = pd.read_excel('C:\\Users\\fresh\\Desktop\\MY_COURSES\\3_TRESTLE_ACADEMY\\Data_Engineering_Track\\African Mobile Data.xlsx')

# %%
df
# Out:
#            Date                      Country           City   Region  \
# 0    2013-01-01                Cote d'Ivoire        Abidjan  Western
# 1    2013-01-01                   Madagascar   Antananarivo  Eastern
# 2    2013-01-01                       Rwanda         Kigali  Eastern
# 3    2013-01-01                     Zimbabwe         Harare  Eastern
# 4    2013-01-02                     Ethiopia    Addis Ababa  Eastern
# ...         ...                          ...            ...      ...
# 1051 2016-12-20                     Zimbabwe         Harare  Eastern
# 1052 2016-12-21                       Malawi       Blantyre  Eastern
# 1053 2016-12-22                      Liberia       Monrovia  Western
# 1054 2016-12-28                        Kenya        Nairobi  Eastern
# 1055 2016-12-28  United Republic of Tanzania  Dar es Salaam  Eastern
#
#           Segment   Sales  Profit
# 0      Commercial  656.96    6.57
# 1          Public  875.94  -70.08
# ...

# %%
ds.structdata.describe(df)
# Out:
# First five data points
#         Date        Country          City   Region      Segment   Sales  \
# 0 2013-01-01  Cote d'Ivoire       Abidjan  Western   Commercial  656.96
# 1 2013-01-01     Madagascar  Antananarivo  Eastern       Public  875.94
# 2 2013-01-01         Rwanda        Kigali  Eastern       Public  258.35
# 3 2013-01-01       Zimbabwe        Harare  Eastern  Residential  875.62
# 4 2013-01-02       Ethiopia   Addis Ababa  Eastern  Residential  509.93
#
#    Profit
# 0    6.57
# 1  -70.08
# 2   18.08
# 3  -35.02
# 4   10.20
# Random five data points
#           Date   Country      City    Region      Segment   Sales  Profit
# 340 2014-02-22   Eritrea    Asmara   Eastern   Commercial  150.97   -6.04
# 101 2013-04-09    Malawi  Lilongwe   Eastern  Residential  809.98   40.50
# 745 2015-09-12  Cameroon    Douala    Middle  Residential  977.32   58.64
# 71  2013-02-18   Algeria   Algiers  Northern  Residential  385.71  -30.86
# ...
